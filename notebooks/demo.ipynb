# %%
import sys
import os

# Add the src directory to the Python path
# This allows you to import your custom package
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# Import functions from your new package
from src.satellite_classifier import load_pretrained_models, classify_satellite_image, visualize_comparison

# --- Step 1: Load Models ---
print("Loading models...")
models = load_pretrained_models()
print("\nModels loaded.")

# --- Step 2: Classify an Image ---
# You can use a local path or a URL
# Example URL (replace with a real satellite image URL if you have one)
# Make sure the URL is directly linkable to an image file (e.g., .jpg, .png)
image_url = "../data/test_1.png"

# If using a local file:
# image_path = "../data/example_images/your_satellite_image.jpg"
# Make sure to create the `data/example_images/` directory and place an image there.
image_path_or_url = image_url

print(f"\nClassifying image from: {image_path_or_url}")
results = classify_satellite_image(models, image_path_or_url)
print("\nClassification complete.")

# --- Step 3: Visualize Comparison ---
print("\nVisualizing results...")
if results:
    visualize_comparison(image_path_or_url, results, title="Satellite Image Classification Comparison in Salzburg")
else:
    print("No results to visualize. Check for errors during classification.")
# Out:
# Loading models...
# ✓ Loaded ResNet50 for EuroSAT (10 land cover classes)
# /home/elouann/.local/lib/python3.13/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/elouann/.local/lib/python3.13/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ✓ Loaded ResNet18 modified for land cover (8 classes)
# ✓ Loaded ResNet18 with ImageNet weights
# ...
